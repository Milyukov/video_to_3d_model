# %%
import pandas as pd
import numpy as np
import seaborn as sns; sns.set()

# %%
results = pd.read_csv('approx_test_results.csv')
results.head()
# Out:
#    Unnamed: 0  proj_id variated_parameter  direction   point.x   point.y  \
# 0           0        0            point.x         -1 -0.497717  0.117736
# 1           1        0            point.x          1 -0.497717  0.117736
# 2           2        0            point.y         -1 -0.497717  0.117736
# 3           3        0            point.y          1 -0.497717  0.117736
# 4           4        0            point.z         -1 -0.497717  0.117736
#
#     point.z  camera.roll  camera.pitch  camera.yaw  ...  camera.t_z  \
# 0 -0.145607            0             0           0  ...        10.0
# 1 -0.145607            0             0           0  ...        10.0
# 2 -0.145607            0             0           0  ...        10.0
# 3 -0.145607            0             0           0  ...        10.0
# 4 -0.145607            0             0           0  ...        10.0
#
#     u_nominal  v_nominal       u_var       v_var   resid_u   resid_v  \
# 0  504.528711  288.83887  509.456953  288.838870  4.928241  0.000000
# 1  504.528711  288.83887  499.600470  288.838870 -4.928241  0.000000
# 2  504.528711  288.83887  504.528711  293.767111  0.000000  4.928241
# 3  504.528711  288.83887  504.528711  283.910628  0.000000 -4.928241
# 4  504.528711  288.83887  504.289304  288.654997 -0.239407 -0.183873
#
#    jcoeffs_u  jcoeffs_v   approx_dist
# 0 -49.282413   0.000000  7.993606e-15
# 1 -49.282413   0.000000  7.993606e-15
# 2   0.000000 -49.282413  7.993606e-15
# 3   0.000000 -49.282413  7.993606e-15
# 4   2.417668   1.856850  2.975367e-03
#
# [5 rows x 22 columns]

# %%
results.sort_values('approx_dist', ascending=False)
# Out:
#       Unnamed: 0  proj_id variated_parameter  direction   point.x   point.y  \
# 1559        1559       86         camera.yaw          1  2.064043  0.028571
# 1523        1523       84         camera.yaw          1  2.030260  0.271539
# 1451        1451       80         camera.yaw          1  1.983633  0.548144
# 1739        1739       96         camera.yaw          1  1.832798  0.951858
# 1685        1685       93         camera.yaw          1  1.837228  0.387556
# ...          ...      ...                ...        ...       ...       ...
# 121          121        6         camera.t_x          1 -0.390443  0.426528
# 120          120        6         camera.t_x         -1 -0.390443  0.426528
# 111          111        6            point.y          1 -0.390443  0.426528
# 110          110        6            point.y         -1 -0.390443  0.426528
# 321          321       17         camera.t_y          1  0.425623  0.463954
#
#        point.z  camera.roll  camera.pitch  camera.yaw  ...  camera.t_z  \
# 1559 -0.628576            0             0           0  ...        10.0
# 1523 -0.844967            0             0           0  ...        10.0
# 1451 -1.143632            0             0           0  ...        10.0
# 1739 -0.545900            0             0           0  ...        10.0
# 1685 -0.546591            0             0           0  ...        10.0
# ...        ...          ...           ...         ...  ...         ...
# 121  -0.319368            0             0           0  ...        10.0
# 120  -0.319368            0             0           0  ...        10.0
# 111  -0.319368            0             0           0  ...        10.0
# 110  -0.319368            0             0           0  ...        10.0
# 321  -0.324844            0             0           0  ...        10.0
#
#        u_nominal   v_nominal       u_var       v_var    resid_u   resid_v  \
# 1559  382.901232  292.177443  360.053755  292.388399 -22.847477  0.210956
# 1523  386.396191  280.533026  363.614424  280.629946 -22.781768  0.096920
# 1451  390.997023  267.839847  368.298417  267.820853 -22.698606 -0.018994
# 1739  393.103783  248.576592  370.441992  248.392223 -22.661791 -0.184368
# 1685  392.899424  275.330831  370.234097  275.376805 -22.665327  0.045973
# ...          ...         ...         ...         ...        ...       ...
# 121   498.917964  273.559921  503.763222  273.559921   4.845258  0.000000
# 120   498.917964  273.559921  494.072706  273.559921  -4.845258  0.000000
# 111   498.917964  273.559921  498.917964  268.714662   0.000000 -4.845258
# 110   498.917964  273.559921  498.917964  278.405179   0.000000  4.845258
# 321   459.388384  271.745618  459.388384  276.588306   0.000000  4.842688
#
#        jcoeffs_u  jcoeffs_v  approx_dist
# 1559 -518.856341   4.306805     0.209370
# 1523 -517.523346   1.971863     0.200847
# 1451 -515.843060  -0.384520     0.190719
# 1739 -515.101905  -3.723226     0.187515
# 1685 -515.173021   0.928637     0.186744
# ...          ...        ...          ...
# 121    48.452582   0.000000     0.000000
# 120    48.452582   0.000000     0.000000
# 111     0.000000 -48.452582     0.000000
# 110     0.000000 -48.452582     0.000000
# 321     0.000000  48.426883     0.000000
#
# [2160 rows x 22 columns]

# %%
sns.catplot(results, x ='variated_parameter', y = 'approx_dist', aspect=2)

# %%
sns.catplot(results, 
            x ='variated_parameter', 
            y = np.linalg.norm(results[['resid_u', 'resid_v']].to_numpy(), axis=1), 
            aspect=2)
